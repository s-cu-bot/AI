# %% [markdown]
# #Linear Regression

# %% [markdown]
# ## Theoretical Overview

# %% [markdown]
# $$ H(x) = Wx + b $$

# %% [markdown]
# $$ cost(W, b) = \frac{1}{m} \sum^m_{i=1} \left( H(x^{(i)}) - y^{(i)} \right)^2 $$

# %% [markdown]
#  - $H(x)$: 주어진 $x$ 값에 대해 예측을 어떻게 할 것인가
#  - $cost(W, b)$: $H(x)$ 가 $y$ 를 얼마나 잘 예측했는가

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# For reproducibility
torch.manual_seed(1)

# %% [markdown]
# ## Data

# %% [markdown]
# We will use fake data for this example.

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])

# %%
print(x_train)
print(x_train.shape)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])
# torch.Size([3, 1])

# %%
print(y_train)
print(y_train.shape)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])
# torch.Size([3, 1])

# %% [markdown]
# ## Weight Initialization

# %%
W = torch.zeros(1, requires_grad=True)
print(W)
# Out:
# tensor([0.], requires_grad=True)

# %%
b = torch.zeros(1, requires_grad=True)
print(b)
# Out:
# tensor([0.], requires_grad=True)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# $$ H(x) = Wx + b $$

# %%
hypothesis = x_train * W + b
print(hypothesis)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], grad_fn=<AddBackward0>)

# %% [markdown]
# ## Cost

# %% [markdown]
# $$ cost(W, b) = \frac{1}{m} \sum^m_{i=1} \left( H(x^{(i)}) - y^{(i)} \right)^2 $$

# %%
print(hypothesis)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], grad_fn=<AddBackward0>)

# %%
print(y_train)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])

# %%
print(hypothesis - y_train)
# Out:
# tensor([[-1.],
#         [-2.],
#         [-3.]], grad_fn=<SubBackward0>)

# %%
print((hypothesis - y_train) ** 2)
# Out:
# tensor([[1.],
#         [4.],
#         [9.]], grad_fn=<PowBackward0>)

# %%
cost = torch.mean((hypothesis - y_train) ** 2)
print(cost)
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## Gradient Descent

# %%
optimizer = optim.SGD([W, b], lr=0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1c81e1459d9e> in <module>()
# ----> 1 optimizer = optim.SGD([W, b], lr=0.01)
#
# NameError: name 'b' is not defined

# %%
optimizer.zero_grad()
cost.backward()
optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4eb598f3a696> in <module>()
# ----> 1 optimizer.zero_grad()
#       2 cost.backward()
#       3 optimizer.step()
#
# NameError: name 'optimizer' is not defined

# %%
print(W)
print(b)

# %% [markdown]
# Let's check if the hypothesis is now better.

# %%
hypothesis = x_train * W + b
print(hypothesis)

# %%
cost = torch.mean((hypothesis - y_train) ** 2)
print(cost)

# %% [markdown]
# ## Training with Full Code

# %% [markdown]
# In reality, we will be training on the dataset for multiple epochs. This can be done simply with loops.

# %%
# 데이터
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])
# 모델 초기화
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)
# optimizer 설정
optimizer = optim.SGD([W, b], lr=0.01)

nb_epochs = 2000
for epoch in range(nb_epochs + 1):
    
    # H(x) 계산
    hypothesis = x_train * W + b
    
    # cost 계산
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            epoch, nb_epochs, W.item(), b.item(), cost.item()
        ))
# Out:
# Epoch    0/2000 W: 0.093, b: 0.040 Cost: 4.666667
# Epoch  100/2000 W: 0.873, b: 0.289 Cost: 0.012043
# Epoch  200/2000 W: 0.900, b: 0.227 Cost: 0.007442
# Epoch  300/2000 W: 0.921, b: 0.179 Cost: 0.004598
# Epoch  400/2000 W: 0.938, b: 0.140 Cost: 0.002842
# Epoch  500/2000 W: 0.951, b: 0.110 Cost: 0.001756
# Epoch  600/2000 W: 0.962, b: 0.087 Cost: 0.001085
# Epoch  700/2000 W: 0.970, b: 0.068 Cost: 0.000670
# Epoch  800/2000 W: 0.976, b: 0.054 Cost: 0.000414
# Epoch  900/2000 W: 0.981, b: 0.042 Cost: 0.000256
# Epoch 1000/2000 W: 0.985, b: 0.033 Cost: 0.000158
# Epoch 1100/2000 W: 0.989, b: 0.026 Cost: 0.000098
# Epoch 1200/2000 W: 0.991, b: 0.020 Cost: 0.000060
# Epoch 1300/2000 W: 0.993, b: 0.016 Cost: 0.000037
# Epoch 1400/2000 W: 0.994, b: 0.013 Cost: 0.000023
# Epoch 1500/2000 W: 0.996, b: 0.010 Cost: 0.000014
# Epoch 1600/2000 W: 0.997, b: 0.008 Cost: 0.000009
# Epoch 1700/2000 W: 0.997, b: 0.006 Cost: 0.000005
# Epoch 1800/2000 W: 0.998, b: 0.005 Cost: 0.000003
# Epoch 1900/2000 W: 0.998, b: 0.004 Cost: 0.000002
# Epoch 2000/2000 W: 0.999, b: 0.003 Cost: 0.000001

# %% [markdown]
# ## High-level Implementation with `nn.Module`

# %% [markdown]
# Remember that we had this fake data.

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])

# %% [markdown]
# 이제 linear regression 모델을 만들면 되는데, 기본적으로 PyTorch의 모든 모델은 제공되는 `nn.Module`을 inherit 해서 만들게 됩니다.

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

# %% [markdown]
# 모델의 `__init__`에서는 사용할 레이어들을 정의하게 됩니다. 여기서 우리는 linear regression 모델을 만들기 때문에, `nn.Linear` 를 이용할 것입니다. 그리고 `forward`에서는 이 모델이 어떻게 입력값에서 출력값을 계산하는지 알려줍니다.

# %%
model = LinearRegressionModel()

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# 이제 모델을 생성해서 예측값 $H(x)$를 구해보자

# %%
hypothesis = model(x_train)

# %%
print(hypothesis)
# Out:
# tensor([[-0.3417],
#         [-1.2832],
#         [-2.2246]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## Cost

# %% [markdown]
# 이제 mean squared error (MSE) 로 cost를 구해보자. MSE 역시 PyTorch에서 기본적으로 제공한다.

# %%
print(hypothesis)
print(y_train)
# Out:
# tensor([[0.0739],
#         [0.5891],
#         [1.1044]], grad_fn=<AddmmBackward>)
# tensor([[1.],
#         [2.],
#         [3.]])

# %%
cost = F.mse_loss(hypothesis, y_train)

# %%
print(cost)
# Out:
# tensor(2.1471, grad_fn=<MseLossBackward>)

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# 마지막 주어진 cost를 이용해 $H(x)$ 의 $W, b$ 를 바꾸어서 cost를 줄여봅니다. 이때 PyTorch의 `torch.optim` 에 있는 `optimizer` 들 중 하나를 사용할 수 있습니다.

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
optimizer.zero_grad()
cost.backward()
optimizer.step()

# %% [markdown]
# ## Training with Full Code

# %% [markdown]
# 이제 Linear Regression 코드를 이해했으니, 실제로 코드를 돌려 피팅시켜보겠습니다.

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

# 데이터
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])
# 모델 초기화
model = LinearRegressionModel()
# optimizer 설정
optimizer = optim.SGD(model.parameters(), lr=0.1)

nb_epochs = 1000
for epoch in range(nb_epochs + 1):
    
    # H(x) 계산
    prediction = model(x_train)
    
    # cost 계산
    cost = F.mse_loss(prediction, y_train)
    
    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    # 100번마다 로그 출력
    if epoch % 100 == 0:
        params = list(model.parameters())
        W = params[0].item()
        b = params[1].item()
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            epoch, nb_epochs, W, b, cost.item()
        ))
# Out:
# Epoch    0/1000 W: 0.932, b: 0.329 Cost: 2.296805
# Epoch  100/1000 W: 0.988, b: 0.026 Cost: 0.000105
# Epoch  200/1000 W: 0.999, b: 0.002 Cost: 0.000001
# Epoch  300/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch  400/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch  500/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch  600/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch  700/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch  800/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch  900/1000 W: 1.000, b: 0.000 Cost: 0.000000
# Epoch 1000/1000 W: 1.000, b: 0.000 Cost: 0.000000

# %% [markdown]
# 점점 $H(x)$ 의 $W$ 와 $b$ 를 조정해서 cost가 줄어드는 것을 볼 수 있습니다.
